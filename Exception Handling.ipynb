# %% [markdown]
# Exception Handling
# ==================

# %%
name=input("Enter your name:")
age=int(input("Enter your age:"))
# Out:
# Enter your name: nesamani
# Enter your age: twenty five
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 name=input("Enter your name:")
# ----> 2 age=int(input("Enter your age:"))
#
# ValueError: invalid literal for int() with base 10: 'twenty five'

# %%
try:
    name=input("Enter your name:")
    age=int(input("Enter your age:"))
except ValueError:
    print("Try only numericals for age.")
    age=int(input("Enter your age:"))
# Out:
# Enter your name: nesamani
# Enter your age: twenty five
# Try only numericals for age.
# Enter your age: 25

# %%
try:
    num1=int(input("Enter your number:"))
    num2=int(input("Enter your number:"))
    print(num1/num2)
except ValueError:
    print("Try only numericals.")
    num1=int(input("Enter your number:"))
    num2=int(input("Enter your number:"))
    print(num1/num2)
except ZeroDivisionError:
    print("Zero can't be a denominator Try another number.")
    num2=int(input("Enter your number:"))
    print(num1/num2)
# Out:
# Enter your number: one
# Try only numericals.
# Enter your number: 5
# Enter your number: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 try:
# ----> 2     num1=int(input("Enter your number:"))
#       3     num2=int(input("Enter your number:"))
#
# ValueError: invalid literal for int() with base 10: 'one'
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 9
#       7     num1=int(input("Enter your number:"))
#       8     num2=int(input("Enter your number:"))
# ----> 9     print(num1/num2)
#      10 except ZeroDivisionError:
#      11     print("Zero can't be a denominator Try another number.")
#
# ZeroDivisionError: division by zero

# %%
def recur():
    try:
        num1=int(input("Enter your number1:"))
        num2=int(input("Enter your number2:"))
        print(num1/num2)
    except ValueError:
        print("Try only numericals.")
        recur()
    except ZeroDivisionError:
        print("Zero can't be a denominator Try another number.")
        recur()

# %%
recur()
# Out:
# Enter your number1: one
# Try only numericals.
# Enter your number1: 6
# Enter your number2: 0
# Zero can't be a denominator Try another number.
# Enter your number1: 3
# Enter your number2: two
# Try only numericals.
# Enter your number1: 6
# Enter your number2: 2
# 3.0

# %%
try:
    num1=int(input("Enter your number:"))
    num2=int(input("Enter your number:"))
    print(num1/num2)
except ValueError:
    print("Try only numericals.")
    num1=int(input("Enter your number:"))
    num2=int(input("Enter your number:"))
    print(num1/num2)
except ZeroDivisionError:
    print("Zero can't be a denominator Try another number.")
    num2=int(input("Enter your number:"))
    print(num1/num2)
else:
    print("No error Occured")
finally:
    print("Program Executed")
# Out:
# Enter your number: 7
# Enter your number: 0
# Zero can't be a denominator Try another number.
# Enter your number: one
# Program Executed
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 4
#       3     num2=int(input("Enter your number:"))
# ----> 4     print(num1/num2)
#       5 except ValueError:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 12
#      10 except ZeroDivisionError:
#      11     print("Zero can't be a denominator Try another number.")
# ---> 12     num2=int(input("Enter your number:"))
#      13     print(num1/num2)
#      14 else:
#
# ValueError: invalid literal for int() with base 10: 'one'

# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.2-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.2-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.4 MB 1.2 MB/s eta 0:00:11
#    -- ------------------------------------- 0.8/12.4 MB 1.2 MB/s eta 0:00:10
#    --- ------------------------------------ 1.0/12.4 MB 1.3 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.3/12.4 MB 1.3 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.8/12.4 MB 1.3 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.4 MB 1.4 MB/s eta 0:00:08
#    ------- -------------------------------- 2.4/12.4 MB 1.4 MB/s eta 0:00:08
#    -------- ------------------------------- 2.6/12.4 MB 1.4 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.1/12.4 MB 1.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.4/12.4 MB 1.5 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.7/12.4 MB 1.5 MB/s eta 0:00:06
#    ------------- -------------------------- 4.2/12.4 MB 1.5 MB/s eta 0:00:06
#    ------------- -------------------------- 4.2/12.4 MB 1.5 MB/s eta 0:00:06
#    --------------- ------------------------ 4.7/12.4 MB 1.5 MB/s eta 0:00:06
#    ---------------- ----------------------- 5.0/12.4 MB 1.5 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.5/12.4 MB 1.5 MB/s eta 0:00:05
#    ------------------ --------------------- 5.8/12.4 MB 1.5 MB/s eta 0:00:05
#    -------------------- ------------------- 6.3/12.4 MB 1.6 MB/s eta 0:00:04
#    --------------------- ------------------ 6.8/12.4 MB 1.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.3/12.4 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 7.9/12.4 MB 1.7 MB/s eta 0:00:03
#    -------------------------- ------------- 8.4/12.4 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.9/12.4 MB 1.8 MB/s eta 0:00:02
#    ------------------------------- -------- 9.7/12.4 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 10.2/12.4 MB 1.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.7/12.4 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.4 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.4 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 2.0 MB/s  0:00:06
# Installing collected packages: numpy
# Successfully installed numpy-2.4.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 2.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.9 MB 2.0 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.9 MB 2.2 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.9 MB 2.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.6/9.9 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.9 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.9 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 3.7/9.9 MB 2.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.9 MB 2.1 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.9 MB 2.1 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/9.9 MB 2.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.5/9.9 MB 2.1 MB/s eta 0:00:03
#    ------------------------ --------------- 6.0/9.9 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.9 MB 2.1 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/9.9 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/9.9 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 7.9/9.9 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.9 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 2.2 MB/s  0:00:04
# Installing collected packages: pandas
# Successfully installed pandas-3.0.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp314-cp314-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 1.1 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/8.3 MB 1.0 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/8.3 MB 1.0 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/8.3 MB 1.0 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.3 MB 1.0 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.3 MB 1.0 MB/s eta 0:00:07
#    -------- ------------------------------- 1.8/8.3 MB 1.0 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.1/8.3 MB 1.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.4/8.3 MB 1.1 MB/s eta 0:00:06
#    ------------- -------------------------- 2.9/8.3 MB 1.1 MB/s eta 0:00:05
#    --------------- ------------------------ 3.1/8.3 MB 1.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 3.7/8.3 MB 1.3 MB/s eta 0:00:04
#    -------------------- ------------------- 4.2/8.3 MB 1.3 MB/s eta 0:00:04
#    --------------------- ------------------ 4.5/8.3 MB 1.4 MB/s eta 0:00:03
#    ------------------------ --------------- 5.0/8.3 MB 1.4 MB/s eta 0:00:03
#    -------------------------- ------------- 5.5/8.3 MB 1.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.3 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.3 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 6.8/8.3 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 7.6/8.3 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.3 MB 1.6 MB/s eta 0:00:01
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ~~~~~~~~~~~~~^^^^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ~~~~~~~~~~~~~^^^^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 102, in read
#     self.__buf.write(data)
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\tempfile.py", line 520, in func_wrapper
#     return func(*args, **kwargs)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\cli\base_command.py", line 107, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\cli\base_command.py", line 98, in _inner_run
#     return self.run(options, args)
#            ~~~~~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\cli\req_command.py", line 85, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\commands\install.py", line 415, in run
#     preparer.prepare_linked_requirements_more(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         requirement_set.requirements.values()
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\operations\prepare.py", line 570, in prepare_linked_requirements_more
#     self._complete_partial_requirements(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         partially_downloaded_reqs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         parallel_builds=parallel_builds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\operations\prepare.py", line 479, in _complete_partial_requirements
#     for link, (filepath, _) in batch_download:
#                                ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\network\download.py", line 184, in batch
#     filepath, content_type = self(link, location)
#                              ~~~~^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\network\download.py", line 195, in __call__
#     self._process_response(download, resp)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\network\download.py", line 212, in _process_response
#     for chunk in chunks:
#                  ^^^^^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\cli\progress_bars.py", line 67, in _rich_download_progress_bar
#     for chunk in iterable:
#                  ^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\network\utils.py", line 65, in response_chunks
#     for chunk in response.raw.stream(
#                  ~~~~~~~~~~~~~~~~~~~^
#         chunk_size,
#         ^^^^^^^^^^^
#     ...<22 lines>...
#         decode_content=False,
#         ^^^^^^^^^^^^^^^^^^^^^
#     ):
#     ^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_vendor\urllib3\response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_vendor\urllib3\response.py", line 560, in read
#     with self._error_catcher():
#          ~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\contextlib.py", line 162, in __exit__
#     self.gen.throw(value)
#     ~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_vendor\urllib3\response.py", line 455, in _error_catcher
#     raise ProtocolError("Connection broken: %r" % e, e)
# pip._vendor.urllib3.exceptions.ProtocolError: ("Connection broken: OSError(28, 'No space left on device')", OSError(28, 'No space left on device'))
