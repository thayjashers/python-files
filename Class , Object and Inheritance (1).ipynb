# %% [markdown]
# Class and Object
# ================

# %%
class bank_account:
    def __init__(self):
        self.name=input("Enter your name:")
        self.age=int(input("Enter your age:"))
        self.amount=int(input("Enter your deposit:"))
    def display(self):
        print("Thanks for Opening Account in Our Bank ",self.name)

# %%
kishore=bank_account()
# Out:
# Enter your name: Kishore
# Enter your age: 20
# Enter your deposit: 1000

# %%
print(kishore.name)
# Out:
# kishore

# %%
Naresh=bank_account()
# Out:
# Enter your name: Naresh
# Enter your age: 19
# Enter your deposit: 2000

# %%
print(Naresh.age)
# Out:
# 19

# %%
Naresh.display()
# Out:
# Thanks for Opening Account in Our Bank

# %%
kishore.display()
# Out:
# Thanks for Opening Account in Our Bank  Kishore

# %%
class school:
    def __init__(self):
        self.name=input("Enter your name: ")
        self.SSLC_Mark=int(input("Enter your 10th Mark: "))
    def group(self):
        if(self.SSLC_Mark>400):
            print("You are going to Group1")
            self.stream="Group1"
        elif(self.SSLC_Mark>300 and self.SSLC_Mark<=400 ):
            print("You are going to Group2")
            self.stream="Group2"
        elif(self.SSLC_Mark>=200 and self.SSLC_Mark<=300 ):
            print("You are going to Group3")
            self.stream="Group3"
        self.HSC_Mark=int(input("Enter your 12th Mark: "))

# %%
class college(school):
    def courses(self):
        if(self.stream=="Group1" and self.HSC_Mark >500):
            print("You are eligible to become an Doctor or Engineer")
        elif(self.stream=="Group2" and self.HSC_Mark >500):
            print("You are eligible to become an Nursing or Teacher")
        elif(self.stream=="Group3" and self.HSC_Mark >500):
            print("You are eligible to become an Manager or Accountant")

# %%
Kathavarayan=school()
# Out:
# Enter your name:  Dhanush
# Enter your 10th Mark:  300

# %%
Kathavarayan.group()
# Out:
# You are going to Group3
# Enter your 12th Mark:  503

# %%
Ramasamy=college()
# Out:
# Enter your name:  Ramasamy
# Enter your 10th Mark:  350

# %%
Ramasamy.group()
# Out:
# You are going to Group2
# Enter your 12th Mark:  515

# %%
Ramasamy.courses()
# Out:
# You are eligible to become an Nursing or Teacher
