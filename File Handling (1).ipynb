# %%
f=open("list.py","r")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='list.py' mode='r' encoding='cp1252'>

# %%
f
# Out:
# <_io.TextIOWrapper name='list.py' mode='r' encoding='cp1252'>

# %%
file=f.read()

# %%
print(file)
# Out:
# a=list(map(int,input().split()))
# a.sort()
# print(*a)

# %%
print(f.read())

# %%
f=open("story.txt","w")

# %%
f
# Out:
# <_io.TextIOWrapper name='story.txt' mode='w' encoding='cp1252'>

# %%
f.write("One")
# Out:
# 3

# %%
f.close()

# %%
f=open("story.txt","r")

# %%
file=f.read()

# %%
file
# Out:
# 'One'

# %%
f=open("story.txt","a")

# %%
f.write(" fine day")
# Out:
# 9

# %%
f.close()

# %%
f=open("story.txt","r")

# %%
file=f.read()

# %%
file
# Out:
# 'One fine day'

# %%
file[:3]
# Out:
# 'One'
